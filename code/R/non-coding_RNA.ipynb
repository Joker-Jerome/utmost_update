# %% [markdown]
# ## Non-coding RNA TWAS

# %%
# Libraries
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.2.1     ✔ purrr   0.3.4
# ✔ tibble  3.0.1     ✔ dplyr   1.0.0
# ✔ tidyr   1.1.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
ln <- load("/ysm-gpfs/pi/zhao-data/zy92/GTEx_V8/processed_data//exp_df_various_biotypes_various_tissues.RData")
ln
# Out:
# [1] "df_list_protein_coding" "df_list_lnc"            "df_list_mirna"

# %%
hist(df_list_mirna[[1]][1, 3:500])

# %%
tmp_exp <- as.numeric(df_list_mirna[[1]][1])
hist(tmp_exp[3:length(tmp_exp)], main = tmp_exp[2])

# %%
hist(log(as.numeric(df_list_mirna[[1]][1, 3:500])))
# Out:
# Plot with title “Histogram of log(as.numeric(df_list_mirna[[1]][1, 3:500]))”

# %%
hist(as.numeric(df_list_mirna[[1]][2, 3:500]))
# Out:
# Plot with title “Histogram of as.numeric(df_list_mirna[[1]][2, 3:500])”

# %%
hist(as.numeric(df_list_mirna[[1]][3, 3:500]))
# Out:
# Plot with title “Histogram of as.numeric(df_list_mirna[[1]][3, 3:500])”

# %%
hist(as.numeric(df_list_lnc[[1]][1, 3:500]))
# Out:
# Plot with title “Histogram of as.numeric(df_list_lnc[[1]][1, 3:500])”

# %%
hist(log(as.numeric(df_list_lnc[[1]][1, 3:500])))
# Out:
# Plot with title “Histogram of log(as.numeric(df_list_lnc[[1]][1, 3:500]))”

# %%
hist(as.numeric(df_list_protein_coding[[1]][1, 3:500]))
# Out:
# Plot with title “Histogram of as.numeric(df_list_protein_coding[[1]][1, 3:500])”

# %%
ln <- load("/ysm-gpfs/pi/zhao-data/zy92/GTEx_V8/processed_data/annotation_complete_chr.RData")
ln
# Out:
# [1] "res_summary"

# %%
ln <- load("/ysm-gpfs/pi/zhao-data/zy92/GTEx_V8/processed_data/exp_df_various_biotypes_various_tissues.RData")
ln
# Out:
# [1] "df_list_protein_coding" "df_list_lnc"            "df_list_mirna"

# %%
length(names(df_list_lnc))

# %%
lapply(df_list_lnc, function(x) dim(x)[2])

# %%
length(df_list_lnc)
# Out:
# [1] 55

# %%
head(df_list_lnc[[1]])
# Out:
#     Name               Description  GTEX-111YS-0006-SM-5NQBE
# 446 ENSG00000175147.11 TMEM51-AS1   0.04117
# 169 ENSG00000177133.10 LINC00982    0.01341
# 358 ENSG00000177553.6  RP11-56N19.5 0.00000
# 48  ENSG00000177757.2  FAM87B       0.00000
# 479 ENSG00000179743.4  FLJ37453     2.91600
# 300 ENSG00000179840.5  PIK3CD-AS1   8.09400
#     GTEX-1122O-0005-SM-5O99J GTEX-1128S-0005-SM-5P9HI GTEX-113IC-0006-SM-5NQ9C
# 446  0.00000                 0.01925                  0.07937
# 169  0.01861                 0.00000                  0.08272
# 358  0.00000                 0.00000                  0.00000
# 48   0.22700                 0.00000                  0.18020
# 479  4.94900                 2.02000                  7.61600
# 300 13.92000                 1.56000                  3.49400
#     GTEX-113JC-0006-SM-5O997 GTEX-117XS-0005-SM-5PNU6 GTEX-117YW-0005-SM-5NQ8Z
# 446 0.01994                  0.00000                  0.01181
# ...

# %%
# sample
data.frame(lapply(df_list_lnc, function(x) dim(x)[2]))

# %%
head(res_summary)
# Out:
#   ensembl_gene_id hgnc_symbol chromosome_name gene_start gene_end
# 1 ENSG00000000003 TSPAN6      X               100627108  100639991
# 2 ENSG00000000005 TNMD        X               100584936  100599885
# 3 ENSG00000000419 DPM1        20               50934867   50958555
# 4 ENSG00000000457 SCYL3       1               169849631  169894267
# 5 ENSG00000000460 C1orf112    1               169662007  169854080
# 6 ENSG00000000938 FGR         1                27612064   27635185
#   ensembl_id
# 1 ENSG00000000003.14
# 2 ENSG00000000005.5
# 3 ENSG00000000419.12
# 4 ENSG00000000457.13
# 5 ENSG00000000460.16
# 6 ENSG00000000938.12

# %%
args

# %%
args <- c("21")

# %%
length(sample_id)
# Out:
# [1] 755

# %%
length(exp_vec)
# Out:
# [1] 755

# %%
head(as.vector(exp_vec))
# Out:
#    GTEX-111YS-0006-SM-5NQBE GTEX-1122O-0005-SM-5O99J GTEX-1128S-0005-SM-5P9HI
# 42 0                        0                        0.09202
#    GTEX-113IC-0006-SM-5NQ9C GTEX-113JC-0006-SM-5O997 GTEX-117XS-0005-SM-5PNU6
# 42 0                        0                        0
#    GTEX-117YW-0005-SM-5NQ8Z GTEX-1192W-0005-SM-5NQBQ GTEX-1192X-0005-SM-5NQC3
# 42 0                        0                        0
#    GTEX-11DXW-0006-SM-5NQ7Y ⋯ GTEX-ZVE2-0006-SM-51MRW GTEX-ZVP2-0005-SM-51MRK
# 42 0                        ⋯ 0                       0
#    GTEX-ZVT2-0005-SM-57WBW GTEX-ZVT3-0006-SM-51MT9 GTEX-ZVT4-0006-SM-57WB8
# 42 0                       0.05341                 0
#    GTEX-ZVTK-0006-SM-57WBK GTEX-ZVZP-0006-SM-51MSW GTEX-ZVZQ-0006-SM-51MR8
# 42 0                       0                       0
#    GTEX-ZXES-0005-SM-57WCB GTEX-ZXG5-0005-SM-57WCN
# 42 0                       0

# %%
output_path <- "/gpfs/project/zhao/zy92/GTEX/expr_gtex_lnc/" ## path for saving outputs of tasks

# create the chr path
    i = 21
    print(paste0("INFO: chr ", i ))
    output_path_chr <- paste0(output_path, "chr", i, "/")
    if (!dir.exists(output_path_chr)) {
        dir.create(output_path_chr, recursive = T)
    }
    
    # subset the specific gene set for the transcript type
    transcriptome_summary <- res_summary %>%
        filter(ensembl_id %in% df_list_lnc[[1]]$Name)
    expression_info_tmp <- transcriptome_summary %>% 
        filter(chromosome_name %in% UQ(i))
    head(expression_info_tmp)
    
    # create the gene dir
    for (gene in expression_info_tmp$ensembl_id) {
        gene_dir <- paste0(output_path_chr, gene)
        if (!dir.exists(gene_dir)) {
            dir.create(gene_dir, recursive = T)
        }
    }
# Out:
# [1] "INFO: chr 21"
#   ensembl_gene_id hgnc_symbol chromosome_name gene_start gene_end
# 1 ENSG00000174680 GRIK1-AS1   21              29748175   29764002
# 2 ENSG00000178457 LINC00314   21              28013363   28023233
# 3 ENSG00000182586 LINC00334   21              45234308   45264548
# 4 ENSG00000182912 TSPEAR-AS2  21              44517216   44525952
# 5 ENSG00000183250 LINC01547   21              44932814   44939937
# 6 ENSG00000183535 COL18A1-AS1 21              45419716   45425070
#   ensembl_id
# 1 ENSG00000174680.9
# 2 ENSG00000178457.3
# 3 ENSG00000182586.8
# 4 ENSG00000182912.6
# 5 ENSG00000183250.11
# 6 ENSG00000183535.9

# %%
class(tmp_exp)
# Out:
# [1] "data.frame"

# %%
as.numeric(tmp_exp[j, 3:ncol(tmp_exp)])
# Out:
#   [1] 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000
#   [9] 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.010690 0.000000
#  [17] 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000
#  [25] 0.013680 0.000000 0.009260 0.000000 0.000000 0.000000 0.000000 0.014270
#  [33] 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000
#  [41] 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000
#  [49] 0.000000 0.000000 0.000000 0.000000 0.000000 0.012210 0.000000 0.000000
#  [57] 0.000000 0.011580 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000
#  [65] 0.000000 0.000000 0.000000 0.000000 0.000000 0.013330 0.000000 0.000000
#  [73] 0.000000 0.022970 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000
#  [81] 0.000000 0.030570 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000
#  [89] 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000 0.000000
# ...

# %%
# tissue-based extraction
tissue_vec_target <- target_tissue_vec <- names(df_list_lnc)[1:49]


for (tissue in tissue_vec_target[1]) {
    tmp_exp <- df_list_lnc[[tissue]] %>%
        filter(Name %in% expression_info_tmp$ensembl_id) %>%
        as.data.frame()
    
    sample_id <- substr(colnames(tmp_exp)[3:ncol(tmp_exp)], 1, 10)
    tmp_gene_vec <- tmp_exp$Name
    for (j in 1:length(tmp_gene_vec) ) {
        if (j %% 100 == 0) { 
            IRdisplay::display_html(paste0("INFO: ", round(j*100/length(tmp_gene_vec), 3), " % processed.")) 
        }
        gene <- tmp_gene_vec[j]
        tmp_file <- paste0(output_path_chr, gene, "/", tissue, ".txt")
        exp_vec <- as.numeric(tmp_exp[j, 3:ncol(tmp_exp)])
        tmp_df <- data.frame(sample_id = sample_id, exp = exp_vec)
        IRdisplay::display_html(paste0("INFO: ", gene))
        write.table(tmp_df, file = tmp_file, row.names = F, col.names = F, quote = F)

    }

}
# Out:
# INFO: ENSG00000274333.4
# INFO: ENSG00000275496.4
# INFO: ENSG00000276077.4
# INFO: ENSG00000277067.4
# INFO: ENSG00000277991.4
# INFO: ENSG00000278878.1
# INFO: ENSG00000278884.1
# INFO: ENSG00000278903.3
# INFO: ENSG00000278927.1
# INFO: ENSG00000278955.3
# INFO: ENSG00000278996.1
# INFO: ENSG00000279064.1
# INFO: ENSG00000279094.3
# INFO: ENSG00000279669.1
# INFO: ENSG00000279687.1
# INFO: ENSG00000279751.1
# INFO: ENSG00000279784.1
# INFO: ENSG00000279998.1
# INFO: ENSG00000280018.3
# INFO: ENSG00000280095.1
# INFO: ENSG00000280145.3
# INFO: ENSG00000280164.1
# INFO: ENSG00000280179.1
# INFO: ENSG00000280191.3
# INFO: ENSG00000280441.2
# INFO: ENSG00000280614.1
# INFO: ENSG00000280800.1
# INFO: ENSG00000281181.1
# INFO: ENSG00000281383.1
# INFO: ENSG00000174680.9
# INFO: ENSG00000178457.3
# INFO: ENSG00000184029.9
# INFO: ENSG00000184856.6
# INFO: ENSG00000185433.8
# INFO: ENSG00000197934.8
# INFO: ENSG00000198054.11
# INFO: ENSG00000205622.9
# INFO: ENSG00000205930.8
# ...

# %%
# Out:
# [1] "GTEX-111YS" "GTEX-1122O" "GTEX-1128S" "GTEX-113IC" "GTEX-113JC"
# [6] "GTEX-117XS" "GTEX-117YW"

# %%
sample_id <- as.character(sapply(colnames(tmp_exp)[3:ncol(tmp_exp)], function(x) 
    paste0(unlist(strsplit(x, split = "-"))[1:2], collapse = "-"))
            )

# %%
sample_id[500:600]
# Out:
#   [1] "GTEX-1RMOY" "GTEX-1RNTQ" "GTEX-1RQEC" "GTEX-1RQED" "GTEX-1S3DN"
#   [6] "GTEX-1S5VW" "GTEX-1S5ZA" "GTEX-1S5ZU" "GTEX-1S82P" "GTEX-1S82U"
#  [11] "GTEX-1S82Y" "GTEX-1S82Z" "GTEX-1S831" "GTEX-1S83E" "GTEX-N7MS"
#  [16] "GTEX-N7MT"  "GTEX-NFK9"  "GTEX-NPJ7"  "GTEX-NPJ8"  "GTEX-O5YT"
#  [21] "GTEX-O5YW"  "GTEX-OHPK"  "GTEX-OHPL"  "GTEX-OHPM"  "GTEX-OHPN"
#  [26] "GTEX-OIZF"  "GTEX-OIZH"  "GTEX-OIZI"  "GTEX-OOBJ"  "GTEX-OOBK"
#  [31] "GTEX-OXRL"  "GTEX-OXRO"  "GTEX-OXRP"  "GTEX-P44G"  "GTEX-P44H"
#  [36] "GTEX-P4PP"  "GTEX-P4PQ"  "GTEX-P4QS"  "GTEX-P78B"  "GTEX-PLZ4"
#  [41] "GTEX-PLZ5"  "GTEX-PLZ6"  "GTEX-POMQ"  "GTEX-POYW"  "GTEX-PSDG"
#  [46] "GTEX-PVOW"  "GTEX-PW2O"  "GTEX-PWCY"  "GTEX-PWN1"  "GTEX-PX3G"
#  [51] "GTEX-Q2AG"  "GTEX-Q2AH"  "GTEX-Q2AI"  "GTEX-Q734"  "GTEX-QCQG"
#  [56] "GTEX-QDT8"  "GTEX-QDVJ"  "GTEX-QDVN"  "GTEX-QEG4"  "GTEX-QEG5"
#  [61] "GTEX-QESD"  "GTEX-QLQ7"  "GTEX-QLQW"  "GTEX-QMR6"  "GTEX-QMRM"
# ...

# %%
head(sample_id)
# Out:
# [1] "GTEX-111YS" "GTEX-1122O" "GTEX-1128S" "GTEX-113IC" "GTEX-113JC"
# [6] "GTEX-117XS"

# %% [markdown]
# # LNC

# %%
strsplit

# %%
# libraries
suppressPackageStartupMessages(library(dplyr))
suppressPackageStartupMessages(library(data.table))

# arguments
# args = commandArgs(trailingOnly=TRUE)
task_index = as.numeric(args[1]) ## a file contains task index
output_path <- "/gpfs/project/zhao/zy92/GTEX/expr_gtex_lnc/" ## path for saving outputs of tasks
## e.g. Rscript --vanilla extract_raw_expression.R chr_idx 

# load("/ysm-gpfs/pi/zhao/zy92/projects/utmost_update/GTEX/raw_expression.RData")
#load("/ysm-gpfs/pi/zhao-data/zy92/GTEx_V8/processed_data/exp_df_various_biotypes_various_tissues.RData")
load("/ysm-gpfs/pi/zhao-data/zy92/GTEx_V8/processed_data/annotation_complete_chr.RData")

tissue_vec_target <- target_tissue_vec <- names(df_list_lnc)[1:49]
# extract the expression level and save in the directory
# loop over chr
#for (i in 1:22) {
for (i in task_index) {   
    
    # create the chr path
    print(paste0("INFO: chr ", i ))
    output_path_chr <- paste0(output_path, "chr", i, "/")
    if (!dir.exists(output_path_chr)) {
        dir.create(output_path_chr, recursive = T)
    }
    
    # subset the specific gene set for the transcript type
    transcriptome_summary <- res_summary %>%
        filter(ensembl_id %in% df_list_lnc[[1]]$Name)
    expression_info_tmp <- transcriptome_summary %>% 
        filter(chromosome_name %in% UQ(i))
    head(expression_info_tmp)
    
    # create the gene dir
    for (gene in expression_info_tmp$ensembl_id) {
        gene_dir <- paste0(output_path_chr, gene)
        if (!dir.exists(gene_dir)) {
            dir.create(gene_dir, recursive = T)
        }
    }
    
    # tissue-based extraction
    for (tissue in tissue_vec_target) {
        tmp_exp <- df_list_lnc[[tissue]] %>%
            filter(Name %in% expression_info_tmp$ensembl_id) %>%
            as.data.frame()
        sample_id <- substr(colnames(tmp_exp)[3:ncol(tmp_exp)], 1, 10)
        tmp_gene_vec <- tmp_exp$Name
        for (j in 1:length(tmp_gene_vec) ) {
            if (j %% 100 == 0) { 
                IRdisplay::display_html(paste0("INFO: ", round(j*100/length(tmp_gene_vec), 3), " % processed.")) 
            }
            gene <- tmp_gene_vec[j]
            tmp_file <- paste0(output_path_chr, gene, "/", tissue, ".txt")
            exp_vec <- as.numeric(tmp_exp[j, 3:ncol(tmp_exp)])
            tmp_df <- data.frame(sample_id = sample_id, exp = exp_vec)
            IRdisplay::display_html(paste0("INFO: ", gene))
            write.table(tmp_df, file = tmp_file, row.names = F, col.names = F, quote = F)
            
        }
       
    }
}

# %%
dim(tmp_exp)
# Out:
# [1] 291 757

# %%
colnames(tmp_exp)[3]
# Out:
# [1] "GTEX-111YS-0006-SM-5NQBE"

# %%
substr(colnames(tmp_exp)[3:10], 1, 10)
# Out:
# [1] "GTEX-111YS" "GTEX-1122O" "GTEX-1128S" "GTEX-113IC" "GTEX-113JC"
# [6] "GTEX-117XS" "GTEX-117YW" "GTEX-1192W"

# %%
gsub(colnames(tmp_exp)[3], 1, 5)
# Out:
# [1] "5"

# %% [markdown]
# # miRNA

# %%
# libraries
suppressPackageStartupMessages(library(dplyr))
suppressPackageStartupMessages(library(data.table))

# arguments
# args = commandArgs(trailingOnly=TRUE)
task_index = as.numeric(args[1]) ## a file contains task index
output_path <- "/gpfs/scratch60/zhao/zy92/GTEX/expr_gtex_mirna/" ## path for saving outputs of tasks
## e.g. Rscript --vanilla extract_raw_expression.R chr_idx 

# load("/ysm-gpfs/pi/zhao/zy92/projects/utmost_update/GTEX/raw_expression.RData")
#load("/ysm-gpfs/pi/zhao-data/zy92/GTEx_V8/processed_data/exp_df_various_biotypes_various_tissues.RData")
load("/ysm-gpfs/pi/zhao-data/zy92/GTEx_V8/processed_data/annotation_complete_chr.RData")

tissue_vec_target <- target_tissue_vec <- names(df_list_mirna)[1:49]
# extract the expression level and save in the directory
# loop over chr
#for (i in 1:22) {
for (i in task_index) {   
    
    # create the chr path
    print(paste0("INFO: chr ", i ))
    output_path_chr <- paste0(output_path, "chr", i, "/")
    if (!dir.exists(output_path_chr)) {
        dir.create(output_path_chr, recursive = T)
    }
    
    # subset the specific gene set for the transcript type
    transcriptome_summary <- res_summary %>%
        filter(ensembl_id %in% df_list_mirna[[1]]$Name)
    expression_info_tmp <- transcriptome_summary %>% 
        filter(chromosome_name %in% UQ(i))
    head(expression_info_tmp)
    
    # create the gene dir
    for (gene in expression_info_tmp$ensembl_id) {
        gene_dir <- paste0(output_path_chr, gene)
        if (!dir.exists(gene_dir)) {
            dir.create(gene_dir, recursive = T)
        }
    }
    
    # tissue-based extraction
    for (tissue in tissue_vec_target) {
        tmp_exp <- df_list_mirna[[tissue]] %>%
            filter(Name %in% expression_info_tmp$ensembl_id) %>%
            as.data.frame()
        sample_id <- substr(colnames(tmp_exp)[3:ncol(tmp_exp)], 1, 10)
        tmp_gene_vec <- tmp_exp$Name
        for (j in 1:length(tmp_gene_vec) ) {
            if (j %% 100 == 0) { 
                IRdisplay::display_html(paste0("INFO: ", round(j*100/length(tmp_gene_vec), 3), " % processed.")) 
            }
            gene <- tmp_gene_vec[j]
            tmp_file <- paste0(output_path_chr, gene, "/", tissue, ".txt")
            exp_vec <- as.numeric(tmp_exp[j, 3:ncol(tmp_exp)])
            tmp_df <- data.frame(sample_id = sample_id, exp = exp_vec)
            IRdisplay::display_html(paste0("INFO: ", gene))
            write.table(tmp_df, file = tmp_file, row.names = F, col.names = F, quote = F)
            
        }
       
    }
}

# %%
# libraries
suppressPackageStartupMessages(library(dplyr))
suppressPackageStartupMessages(library(data.table))

# arguments
args = commandArgs(trailingOnly=TRUE)
task_index = args[1] ## a file contains task index
output_path <- "/gpfs/project/zhao/zy92/GTEX/expr_gtex_lnc/" ## path for saving outputs of tasks
## e.g. Rscript --vanilla extract_raw_expression.R chr_idx 

# load("/ysm-gpfs/pi/zhao/zy92/projects/utmost_update/GTEX/raw_expression.RData")
load("/ysm-gpfs/pi/zhao-data/zy92/GTEx_V8/processed_data/exp_df_various_biotypes_various_tissues.RData")
load("/ysm-gpfs/pi/zhao-data/zy92/GTEx_V8/processed_data/annotation_complete_chr.RData")

tissue_vec_target <- target_tissue_vec <- names(df_list_lnc)[1:49]
# extract the expression level and save in the directory
# loop over chr
#for (i in 1:22) {
for (i in task_index) {   
    
    # create the chr path
    print(paste0("INFO: chr ", i ))
    output_path_chr <- paste0(output_path, "chr", i, "/")
    if (!dir.exists(output_path_chr)) {
        dir.create(output_path_chr, recursive = T)
    }
    
    # subset the specific gene set for the transcript type
    transcriptome_summary <- res_summary %>%
        filter(ensembl_id %in% df_list_lnc[[1]]$Name)
    expression_info_tmp <- transcriptome_summary %>% 
        filter(chromosome_name %in% UQ(i))
    head(expression_info_tmp)
    
    # gene id vec
    ensembl_vec <- expression_info_tmp$ensembl_gene_id
    gene_vec <- expression_info_tmp$hgnc_symbol
    
    # extract the expression files
    expression_list_target_chr <- list()
    n_sample <- list()
    #expression_list_target_chr[[i]] <- list()
    for (tissue in tissue_vec_target) {
        tmp_exp <- expression_info_tmp %>%
            left_join(expression_list_[[tissue]], by = c("ensembl_gene_id" = "ensembl_gene_id"))
        expression_list_target_chr[[tissue]] <- tmp_exp
        n_sample[[tissue]] <- ncol(tmp_exp) - 9
        #print(n_sample[[tissue]])
    }
    
    # tissue-specific sample id 
    id_vec <- list()
    for (tissue in tissue_vec_target) {
        id_vec[[tissue]] <- colnames(expression_list_target_chr[[tissue]])[8:(7+as.numeric(n_sample[[tissue]]))]

    }
    # loop over gene
    #gene2idx <- list()
    #idx <- match(gene, )
    
    for (j in 1:length(gene_vec)) {
    #for (j in 1:1) {
        gene <- gene_vec[j]
        # watch the process
        if (j %% 100 == 0) { 
            print(paste0("INFO: ", round(j*100/length(gene_vec), 3), " % processed.")) 
        }
        output_path_chr_gene <- paste0(output_path_chr, gene)
        if (!dir.exists(output_path_chr_gene)) {
            dir.create(output_path_chr_gene, recursive = T)
        } 
        
        # loop over tissue
        for (tissue in tissue_vec_target) {
            tissue_file_name <- paste0(output_path_chr_gene, "/", tissue, ".txt")
            #exp_vec <- expression_list_target_chr[[tissue]] %>% 
                #filter(ensembl_gene_id == gene)
            exp_vec <- expression_list_target_chr[[tissue]][j,]
            #print(dim(exp_vec))
            #print(n_sample[[tissue]])
            #print(exp_vec[, 1:20])
            exp_vec <- as.numeric(exp_vec[,8:(7+as.numeric(n_sample[[tissue]]))])
            #print(head(exp_vec))
            #id_vec <- colnames(expression_list_target_chr[[tissue]])[8:(7+as.numeric(n_sample[[tissue]]))]
            output_df <- data.frame(id = id_vec[[tissue]], exp = exp_vec)
            write.table(output_df, file = tissue_file_name, row.names = F, col.names = F, quote = F)
        }
        
    }
    
}

# %% [markdown]
# # related genes

# %%
# Libraries
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.2.1     ✔ purrr   0.3.4
# ✔ tibble  3.0.1     ✔ dplyr   1.0.0
# ✔ tidyr   1.1.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
anno_df = "/ysm-gpfs/pi/zhao-data/zy92/GTEx_V8/processed_data/annotation_complete_chr.RData"
ln <- load(anno_df)   
ln
# Out:
# [1] "res_summary"

# %%
ln <- load("/ysm-gpfs/pi/zhao-data/zy92/GTEx_V8/processed_data//exp_df_various_biotypes_various_tissues.RData")
ln
# Out:
# [1] "df_list_protein_coding" "df_list_lnc"            "df_list_mirna"

# %%
head(res_summary)
# Out:
#   ensembl_gene_id hgnc_symbol chromosome_name gene_start gene_end
# 1 ENSG00000000003 TSPAN6      X               100627108  100639991
# 2 ENSG00000000005 TNMD        X               100584936  100599885
# 3 ENSG00000000419 DPM1        20               50934867   50958555
# 4 ENSG00000000457 SCYL3       1               169849631  169894267
# 5 ENSG00000000460 C1orf112    1               169662007  169854080
# 6 ENSG00000000938 FGR         1                27612064   27635185
#   ensembl_id
# 1 ENSG00000000003.14
# 2 ENSG00000000005.5
# 3 ENSG00000000419.12
# 4 ENSG00000000457.13
# 5 ENSG00000000460.16
# 6 ENSG00000000938.12

# %%
related_genes = c("SWR1", "ISW2", "RSC", "INO80", "DICER1", "MYC", "CAF-1", "SWI/SNF")

# %%
res_summary %>% 
    filter(hgnc_symbol %in% related_genes)
# Out:
#   ensembl_gene_id hgnc_symbol chromosome_name gene_start gene_end
# 1 ENSG00000100697 DICER1      14               95086228   95158010
# 2 ENSG00000128908 INO80       15               40978880   41116280
# 3 ENSG00000136997 MYC         8               127735434  127742951
#   ensembl_id
# 1 ENSG00000100697.14
# 2 ENSG00000128908.15
# 3 ENSG00000136997.16

# %%
res_summary %>% 
    filter(hgnc_symbol %in% c("DROSHA", "DICER1"))
# Out:
#   ensembl_gene_id hgnc_symbol chromosome_name gene_start gene_end
# 1 ENSG00000100697 DICER1      14              95086228   95158010
# 2 ENSG00000113360 DROSHA      5               31400497   31532196
#   ensembl_id
# 1 ENSG00000100697.14
# 2 ENSG00000113360.16

# %%
df_list_protein_coding[[1]][1:6, 1:6]
# Out:
#     Name               Description GTEX-111YS-0006-SM-5NQBE
# 233 ENSG00000007923.15 DNAJC11       4.4060
# 127 ENSG00000008128.22 CDK11A       15.3900
# 130 ENSG00000008130.15 NADK        157.8000
# 334 ENSG00000009724.16 MASP2         0.4303
# 360 ENSG00000011021.21 CLCN6         3.6020
# 379 ENSG00000028137.18 TNFRSF1B    469.0000
#     GTEX-1122O-0005-SM-5O99J GTEX-1128S-0005-SM-5P9HI GTEX-113IC-0006-SM-5NQ9C
# 233   3.556                    4.302                   14.03
# 127  21.090                   25.490                   23.53
# 130 357.400                   61.150                  265.10
# 334   2.307                    2.484                    5.31
# 360   3.837                    8.592                   18.42
# 379 512.000                  873.500                  743.40

# %%
dim(df_list_protein_coding[[1]])
# Out:
# [1] 19207   757

# %%
df_list_protein_coding[[1]] %>%
    filter(Description %in% c("DROSHA", "DICER1", "INO80", "MYC"))
# Out:
#   Name               Description GTEX-111YS-0006-SM-5NQBE
# 1 ENSG00000113360.16 DROSHA       2.630
# 2 ENSG00000136997.16 MYC         16.210
# 3 ENSG00000100697.14 DICER1      14.160
# 4 ENSG00000128908.15 INO80        5.159
#   GTEX-1122O-0005-SM-5O99J GTEX-1128S-0005-SM-5P9HI GTEX-113IC-0006-SM-5NQ9C
# 1  2.979                    4.228                   11.60
# 2 24.700                   15.370                   36.51
# 3 37.930                   10.810                   26.50
# 4  5.951                    4.532                   14.39
#   GTEX-113JC-0006-SM-5O997 GTEX-117XS-0005-SM-5PNU6 GTEX-117YW-0005-SM-5NQ8Z
# 1 2.037                    2.7540                    6.299
# 2 5.684                    4.4590                   16.850
# 3 6.189                    0.7345                    2.691
# 4 2.608                    2.2750                    7.345
#   GTEX-1192W-0005-SM-5NQBQ ⋯ GTEX-ZVE2-0006-SM-51MRW GTEX-ZVP2-0005-SM-51MRK
# ...

# %%
df_list_related_genes <- lapply(df_list_protein_coding, function(x) 
    x %>%
    filter(Description %in% c("DROSHA", "DICER1", "INO80", "MYC")) )

# %%
df_list_related_genes
# Out:
# $Whole_Blood
#                 Name Description GTEX-111YS-0006-SM-5NQBE
# 1 ENSG00000113360.16      DROSHA                    2.630
# 2 ENSG00000136997.16         MYC                   16.210
# 3 ENSG00000100697.14      DICER1                   14.160
# 4 ENSG00000128908.15       INO80                    5.159
#   GTEX-1122O-0005-SM-5O99J GTEX-1128S-0005-SM-5P9HI GTEX-113IC-0006-SM-5NQ9C
# 1                    2.979                    4.228                    11.60
# 2                   24.700                   15.370                    36.51
# 3                   37.930                   10.810                    26.50
# 4                    5.951                    4.532                    14.39
#   GTEX-113JC-0006-SM-5O997 GTEX-117XS-0005-SM-5PNU6 GTEX-117YW-0005-SM-5NQ8Z
# 1                    2.037                   2.7540                    6.299
# 2                    5.684                   4.4590                   16.850
# ...

# %%
save(df_list_related_genes, file = "/ysm-gpfs/pi/zhao-data/zy92/GTEx_V8/processed_data/exp_list_related_genes.RData")

# %%
head(t(df_list_related_genes[[1]]))
# Out:
#                          [,1]               [,2]
# Name                     ENSG00000113360.16 ENSG00000136997.16
# Description              DROSHA             MYC
# GTEX-111YS-0006-SM-5NQBE  2.630             16.210
# GTEX-1122O-0005-SM-5O99J  2.979             24.700
# GTEX-1128S-0005-SM-5P9HI  4.228             15.370
# GTEX-113IC-0006-SM-5NQ9C 11.60              36.51
#                          [,3]               [,4]
# Name                     ENSG00000100697.14 ENSG00000128908.15
# Description              DICER1             INO80
# GTEX-111YS-0006-SM-5NQBE 14.160              5.159
# GTEX-1122O-0005-SM-5O99J 37.930              5.951
# GTEX-1128S-0005-SM-5P9HI 10.810              4.532
# GTEX-113IC-0006-SM-5NQ9C 26.50              14.39

# %%
head(df_list_mirna[[1]])
# Out:
#     Name              Description GTEX-111YS-0006-SM-5NQBE
# 76  ENSG00000198976.1 MIR429      0
# 75  ENSG00000207607.3 MIR200A     0
# 74  ENSG00000207730.3 MIR200B     0
# 178 ENSG00000207776.1 MIR551A     0
# 380 ENSG00000263676.1 MIR4632     0
# 207 ENSG00000264101.1 MIR4689     0
#     GTEX-1122O-0005-SM-5O99J GTEX-1128S-0005-SM-5P9HI GTEX-113IC-0006-SM-5NQ9C
# 76  0.0000                   0                        0
# 75  0.0000                   0                        0
# 74  0.5486                   0                        0
# 178 0.0000                   0                        0
# 380 0.0000                   0                        0
# 207 0.0000                   0                        0
#     GTEX-113JC-0006-SM-5O997 GTEX-117XS-0005-SM-5PNU6 GTEX-117YW-0005-SM-5NQ8Z
# 76  0                        0                        0.0000
# 75  0                        0                        0.0000
# 74  0                        0                        0.0000
# ...

# %%
head(df_list_related_genes[[1]])
# Out:
#   Name               Description GTEX-111YS-0006-SM-5NQBE
# 1 ENSG00000113360.16 DROSHA       2.630
# 2 ENSG00000136997.16 MYC         16.210
# 3 ENSG00000100697.14 DICER1      14.160
# 4 ENSG00000128908.15 INO80        5.159
#   GTEX-1122O-0005-SM-5O99J GTEX-1128S-0005-SM-5P9HI GTEX-113IC-0006-SM-5NQ9C
# 1  2.979                    4.228                   11.60
# 2 24.700                   15.370                   36.51
# 3 37.930                   10.810                   26.50
# 4  5.951                    4.532                   14.39
#   GTEX-113JC-0006-SM-5O997 GTEX-117XS-0005-SM-5PNU6 GTEX-117YW-0005-SM-5NQ8Z
# 1 2.037                    2.7540                    6.299
# 2 5.684                    4.4590                   16.850
# 3 6.189                    0.7345                    2.691
# 4 2.608                    2.2750                    7.345
#   GTEX-1192W-0005-SM-5NQBQ ⋯ GTEX-ZVE2-0006-SM-51MRW GTEX-ZVP2-0005-SM-51MRK
# ...

# %%
getwd()
# Out:
# [1] "/gpfs/loomis/project/zhao/zy92/utmost_update/utmost_update/code/R"

# %%
length(tissue_vec)
# Out:
# [1] 55

# %%
tissue_vec <- names(df_list_mirna)
cor_list <- list()
for (tissue in tissue_vec[1:49] ) {
    IRdisplay::display_html(paste0("INFO: ", tissue))
    corr_vec <- apply(df_list_mirna[[tissue]], 1, function(x) {
            vec_a <- x[3:length(x)]
            na_idx <- is.na(vec_a)
            if (sum(na_idx) != 0) {
                vec_a <- vec_a[!na_idx]
            }
            vec_a <- as.numeric(vec_a)
            if (sum(vec_a == 0) == length(vec_a)) {
                0
            } else {
                vec_b <- as.numeric(df_list_related_genes[[tissue]][1, 3:length(x)])[!na_idx]
                cor(vec_a, vec_b) 
            }
        }
        )
    cor_list[[tissue]] <- corr_vec
    }
# Out:
# INFO: Whole_Blood
# INFO: Brain_Frontal_Cortex_BA9
# INFO: Adipose_Subcutaneous
# INFO: Muscle_Skeletal
# INFO: Artery_Tibial
# INFO: Artery_Coronary
# INFO: Heart_Atrial_Appendage
# INFO: Adipose_Visceral_Omentum
# INFO: Ovary
# INFO: Uterus
# INFO: Vagina
# INFO: Breast_Mammary_Tissue
# INFO: Skin_Not_Sun_Exposed_Suprapubic
# INFO: Minor_Salivary_Gland
# INFO: Brain_Cortex
# INFO: Adrenal_Gland
# INFO: Thyroid
# INFO: Lung
# INFO: Spleen
# INFO: Pancreas
# INFO: Esophagus_Muscularis
# INFO: Esophagus_Mucosa
# INFO: Esophagus_Gastroesophageal_Junction
# INFO: Stomach
# INFO: Colon_Sigmoid
# INFO: Small_Intestine_Terminal_Ileum
# INFO: Colon_Transverse
# INFO: Prostate
# INFO: Testis
# INFO: Skin_Sun_Exposed_Lower_leg
# INFO: Nerve_Tibial
# INFO: Heart_Left_Ventricle
# INFO: Pituitary
# INFO: Brain_Cerebellum
# INFO: Cells_Cultured_fibroblasts
# INFO: Artery_Aorta
# INFO: Cells_EBV-transformed_lymphocytes
# INFO: Brain_Cerebellar_Hemisphere
# INFO: Brain_Caudate_basal_ganglia
# ...

# %%
cor_drosha <- cor_list

# %%
tissue_vec <- names(df_list_mirna)
cor_list <- list()
for (tissue in tissue_vec[1:49] ) {
    IRdisplay::display_html(paste0("INFO: ", tissue))
    corr_vec <- apply(df_list_mirna[[tissue]], 1, function(x) {
            vec_a <- x[3:length(x)]
            na_idx <- is.na(vec_a)
            if (sum(na_idx) != 0) {
                vec_a <- vec_a[!na_idx]
            }
            vec_a <- as.numeric(vec_a)
            if (sum(vec_a == 0) == length(vec_a)) {
                0
            } else {
                vec_b <- as.numeric(df_list_related_genes[[tissue]][2, 3:length(x)])[!na_idx]
                cor(vec_a, vec_b) 
            }
        }
        )
    cor_list[[tissue]] <- corr_vec
    }
cor_list_myc <- cor_list
# Out:
# INFO: Whole_Blood
# INFO: Brain_Frontal_Cortex_BA9
# INFO: Adipose_Subcutaneous
# INFO: Muscle_Skeletal
# INFO: Artery_Tibial
# INFO: Artery_Coronary
# INFO: Heart_Atrial_Appendage
# INFO: Adipose_Visceral_Omentum
# INFO: Ovary
# INFO: Uterus
# INFO: Vagina
# INFO: Breast_Mammary_Tissue
# INFO: Skin_Not_Sun_Exposed_Suprapubic
# INFO: Minor_Salivary_Gland
# INFO: Brain_Cortex
# INFO: Adrenal_Gland
# INFO: Thyroid
# INFO: Lung
# INFO: Spleen
# INFO: Pancreas
# INFO: Esophagus_Muscularis
# INFO: Esophagus_Mucosa
# INFO: Esophagus_Gastroesophageal_Junction
# INFO: Stomach
# INFO: Colon_Sigmoid
# INFO: Small_Intestine_Terminal_Ileum
# INFO: Colon_Transverse
# INFO: Prostate
# INFO: Testis
# INFO: Skin_Sun_Exposed_Lower_leg
# INFO: Nerve_Tibial
# INFO: Heart_Left_Ventricle
# INFO: Pituitary
# INFO: Brain_Cerebellum
# INFO: Cells_Cultured_fibroblasts
# INFO: Artery_Aorta
# INFO: Cells_EBV-transformed_lymphocytes
# INFO: Brain_Cerebellar_Hemisphere
# INFO: Brain_Caudate_basal_ganglia
# ...

# %%
tissue_vec <- names(df_list_mirna)
cor_list <- list()
for (tissue in tissue_vec[1:49] ) {
    IRdisplay::display_html(paste0("INFO: ", tissue))
    corr_vec <- apply(df_list_mirna[[tissue]], 1, function(x) {
            vec_a <- x[3:length(x)]
            na_idx <- is.na(vec_a)
            if (sum(na_idx) != 0) {
                vec_a <- vec_a[!na_idx]
            }
            vec_a <- as.numeric(vec_a)
            if (sum(vec_a == 0) == length(vec_a)) {
                0
            } else {
                vec_b <- as.numeric(df_list_related_genes[[tissue]][3, 3:length(x)])[!na_idx]
                cor(vec_a, vec_b) 
            }
        }
        )
    cor_list[[tissue]] <- corr_vec
    }
cor_list_dicer <- cor_list
# Out:
# INFO: Whole_Blood
# INFO: Brain_Frontal_Cortex_BA9
# INFO: Adipose_Subcutaneous
# INFO: Muscle_Skeletal
# INFO: Artery_Tibial
# INFO: Artery_Coronary
# INFO: Heart_Atrial_Appendage
# INFO: Adipose_Visceral_Omentum
# INFO: Ovary
# INFO: Uterus
# INFO: Vagina
# INFO: Breast_Mammary_Tissue
# INFO: Skin_Not_Sun_Exposed_Suprapubic
# INFO: Minor_Salivary_Gland
# INFO: Brain_Cortex
# INFO: Adrenal_Gland
# INFO: Thyroid
# INFO: Lung
# INFO: Spleen
# INFO: Pancreas
# INFO: Esophagus_Muscularis
# INFO: Esophagus_Mucosa
# INFO: Esophagus_Gastroesophageal_Junction
# INFO: Stomach
# INFO: Colon_Sigmoid
# INFO: Small_Intestine_Terminal_Ileum
# INFO: Colon_Transverse
# INFO: Prostate
# INFO: Testis
# INFO: Skin_Sun_Exposed_Lower_leg
# INFO: Nerve_Tibial
# INFO: Heart_Left_Ventricle
# INFO: Pituitary
# INFO: Brain_Cerebellum
# INFO: Cells_Cultured_fibroblasts
# INFO: Artery_Aorta
# INFO: Cells_EBV-transformed_lymphocytes
# INFO: Brain_Cerebellar_Hemisphere
# INFO: Brain_Caudate_basal_ganglia
# ...

# %%
tissue_vec <- names(df_list_mirna)
cor_list <- list()
for (tissue in tissue_vec[1:49] ) {
    IRdisplay::display_html(paste0("INFO: ", tissue))
    corr_vec <- apply(df_list_mirna[[tissue]], 1, function(x) {
            vec_a <- x[3:length(x)]
            na_idx <- is.na(vec_a)
            if (sum(na_idx) != 0) {
                vec_a <- vec_a[!na_idx]
            }
            vec_a <- as.numeric(vec_a)
            if (sum(vec_a == 0) == length(vec_a)) {
                0
            } else {
                vec_b <- as.numeric(df_list_related_genes[[tissue]][4, 3:length(x)])[!na_idx]
                cor(vec_a, vec_b) 
            }
        }
        )
    cor_list[[tissue]] <- corr_vec
    }
cor_list_ino80 <- cor_list
# Out:
# INFO: Whole_Blood
# INFO: Brain_Frontal_Cortex_BA9
# INFO: Adipose_Subcutaneous
# INFO: Muscle_Skeletal
# INFO: Artery_Tibial
# INFO: Artery_Coronary
# INFO: Heart_Atrial_Appendage
# INFO: Adipose_Visceral_Omentum
# INFO: Ovary
# INFO: Uterus
# INFO: Vagina
# INFO: Breast_Mammary_Tissue
# INFO: Skin_Not_Sun_Exposed_Suprapubic
# INFO: Minor_Salivary_Gland
# INFO: Brain_Cortex
# INFO: Adrenal_Gland
# INFO: Thyroid
# INFO: Lung
# INFO: Spleen
# INFO: Pancreas
# INFO: Esophagus_Muscularis
# INFO: Esophagus_Mucosa
# INFO: Esophagus_Gastroesophageal_Junction
# INFO: Stomach
# INFO: Colon_Sigmoid
# INFO: Small_Intestine_Terminal_Ileum
# INFO: Colon_Transverse
# INFO: Prostate
# INFO: Testis
# INFO: Skin_Sun_Exposed_Lower_leg
# INFO: Nerve_Tibial
# INFO: Heart_Left_Ventricle
# INFO: Pituitary
# INFO: Brain_Cerebellum
# INFO: Cells_Cultured_fibroblasts
# INFO: Artery_Aorta
# INFO: Cells_EBV-transformed_lymphocytes
# INFO: Brain_Cerebellar_Hemisphere
# INFO: Brain_Caudate_basal_ganglia
# ...

# %%
nrow(df_list_protein_coding[[3]])
# Out:
# [1] 19207

# %%
cor_list_gene <- list()
gene_vec <- df_list_protein_coding[[1]][, 2]
tissue_vec <- names(df_list_mirna)


for (i in 1:50) {
    

    IRdisplay::display_html(paste0("INFO: gene ", i))
    cor_list <- list()
    for (tissue in tissue_vec[1:49] ) {

        corr_vec <- apply(df_list_mirna[[tissue]], 1, function(x) {
                vec_a <- x[3:length(x)]
                na_idx <- is.na(vec_a)
                if (sum(na_idx) != 0) {
                    vec_a <- vec_a[!na_idx]
                }
                vec_a <- as.numeric(vec_a)
                if (sum(vec_a == 0) == length(vec_a)) {
                    0
                } else {
                    vec_b <- as.numeric(df_list_protein_coding[[tissue]][i, 3:length(x)])[!na_idx]
                    cor(vec_a, vec_b) 
                }
            }
            )
        cor_list[[tissue]] <- corr_vec
    }
    cor_list_gene[[gene_vec[i]]] <- cor_list
}
# Out:
# INFO: gene 1
# INFO: gene 2
# INFO: gene 3
# INFO: gene 4
# INFO: gene 5
# INFO: gene 6
# INFO: gene 7
# INFO: gene 8
# INFO: gene 9
# INFO: gene 10
# INFO: gene 11
# INFO: gene 12
# INFO: gene 13
# INFO: gene 14
# INFO: gene 15
# INFO: gene 16
# INFO: gene 17
# INFO: gene 18
# INFO: gene 19
# INFO: gene 20
# INFO: gene 21
# INFO: gene 22
# INFO: gene 23
# INFO: gene 24
# INFO: gene 25
# INFO: gene 26
# INFO: gene 27
# INFO: gene 28
# INFO: gene 29
# INFO: gene 30
# INFO: gene 31
# INFO: gene 32
# INFO: gene 33
# INFO: gene 34
